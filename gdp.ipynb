# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
path="csv_data/states.csv"
state_ab=pd.read_csv(path,encoding="ISO-8859-1")
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",500)

# %%
path = "csv_data/GDP_States_2017_2022.csv"
gdp_data=pd.read_csv(path,encoding="ISO-8859-1")
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",500)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
gdp_data.head(5)
# Out:
#     GeoFIPS        GeoName Region TableName  LineCode IndustryClassification  \
# 0   "00000"  United States           SAGDP1      1.00                    ...
# 1   "00000"  United States           SAGDP1      2.00                    ...
# 2   "00000"  United States           SAGDP1      3.00                    ...
# 3   "00000"  United States           SAGDP1      4.00                    ...
# 4   "00000"  United States           SAGDP1      5.00                    ...
#
#                                          Description  \
# 0     Real GDP (millions of chained 2017 dollars) 1/
# 1          Chain-type quantity indexes for real GDP
# 2  Current-dollar GDP (millions of current dollars)
# 3                Compensation (millions of dollars)
# 4     Gross operating surplus (millions of dollars)
#
#                                Unit        2017        2018        2019  \
# 0  Millions of chained 2017 dollars 19612102.00 20193896.00 20692087.00
# 1                    Quantity index      100.00      102.97      105.51
# 2       Millions of current dollars 19612102.00 20656516.00 21521395.00
# 3       Millions of current dollars 10434978.00 10967687.00 11459776.00
# 4       Millions of current dollars  7873027.00  8295055.00  8601459.00
#
#          2020        2021        2022
# 0 20234074.00 21407692.00 21822037.00
# 1      103.17      109.16      111.27
# 2 21322950.00 23594031.00 25744108.00
# 3 11602288.00 12556629.00 13455238.00
# 4  8857004.00  9848221.00 10606096.00

# %%
new=(gdp_data["LineCode"] == 1.00)
state_gdp = gdp_data.loc[new]
col=["GeoName","Unit","2017","2018","2019","2020","2021","2022"]
state_gdp=state_gdp[col]
state_gdp=state_gdp.rename(columns={"GeoName":"State"})
state_gdp.set_index("State").head()
# Out:
#                                            Unit        2017        2018  \
# State
# United States  Millions of chained 2017 dollars 19612102.00 20193896.00
# Alabama        Millions of chained 2017 dollars   216615.50   220808.80
# Alaska         Millions of chained 2017 dollars    53550.90    52479.60
# Arizona        Millions of chained 2017 dollars   333099.00   346398.30
# Arkansas       Millions of chained 2017 dollars   123882.60   126371.20
#
#                      2019        2020        2021        2022
# State
# United States 20692087.00 20234074.00 21407692.00 21822037.00
# Alabama         224944.60   222081.40   231892.60   235807.30
# Alaska           52325.30    50344.60    51021.80    50315.10
# Arizona         359645.70   362603.50   390805.20   403474.20
# Arkansas        127216.00   128061.20   135568.80   137355.50

# %%
state_ab.head()
# Out:
#         State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
merge_df1 = pd.merge(left= state_gdp, right=state_ab,on="State",how="left")
merge_df1.head()
# Out:
#            State                              Unit        2017        2018  \
# 0  United States  Millions of chained 2017 dollars 19612102.00 20193896.00
# 1        Alabama  Millions of chained 2017 dollars   216615.50   220808.80
# 2         Alaska  Millions of chained 2017 dollars    53550.90    52479.60
# 3        Arizona  Millions of chained 2017 dollars   333099.00   346398.30
# 4       Arkansas  Millions of chained 2017 dollars   123882.60   126371.20
#
#          2019        2020        2021        2022 Abbreviation
# 0 20692087.00 20234074.00 21407692.00 21822037.00          NaN
# 1   224944.60   222081.40   231892.60   235807.30           AL
# 2    52325.30    50344.60    51021.80    50315.10           AK
# 3   359645.70   362603.50   390805.20   403474.20           AZ
# 4   127216.00   128061.20   135568.80   137355.50           AR

# %%
merge_df1= merge_df1.dropna(how="any")
merge_df1 =merge_df1[["State","Abbreviation","Unit","2022"]]
merge_df1.sort_values(by="2022",ascending=False)
# Out:
#                    State Abbreviation                              Unit  \
# 5             California           CA  Millions of chained 2017 dollars
